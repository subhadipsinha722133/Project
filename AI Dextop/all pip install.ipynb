# %%
# !pip install pyttsx3
# Out:
# ...
#   Using cached pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached comtypes-1.4.11-py3-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# ...
# Using cached pyttsx3-2.99-py3-none-any.whl (32 kB)
# Using cached comtypes-1.4.11-py3-none-any.whl (246 kB)
# Using cached pypiwin32-223-py3-none-any.whl (1.7 kB)
# ...
#
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    -------------------------- ------------- 2/3 [pyttsx3]
#    ---------------------------------------- 3/3 [pyttsx3]
#
# ...

# %%
# !pip install SpeechRecognition
# Out:
# ...
#   Using cached speechrecognition-3.14.3-py3-none-any.whl.metadata (30 kB)
# ...
# Using cached speechrecognition-3.14.3-py3-none-any.whl (32.9 MB)
# ...

# %%
# !pip install PyAudio

# %%
# !pip install wikipedia
# Out:
# ...
#   Using cached wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11785 sha256=5749f915f717a67d10bea0441f04550651b67d798b1e8809d46b92e82ee64f0b
#   Stored in directory: c:\users\sinha\appdata\local\pip\cache\wheels\8f\ab\cb\45ccc40522d3a1c41e1d2ad53b8f33a62f394011ec38cd71c6
# Successfully built wikipedia
# ...
#
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ---------------------------------------- 3/3 [wikipedia]
#
# ...

# %%
# !pip install pywhatkit
# Out:
# ...
#   Using cached pywhatkit-5.4-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached PyAutoGUI-0.9.54.tar.gz (61 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached pytweening-1.2.0.tar.gz (171 kB)
#   Preparing metadata (setup.py): started
# ...
