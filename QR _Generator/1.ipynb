# %%
# !pip install qecode
# Out:
# ERROR: Could not find a version that satisfies the requirement qecode (from versions: none)
# ERROR: No matching distribution found for qecode

# %%
# !pip install qrcode
# Out:
# ...
#   Using cached qrcode-8.2-py3-none-any.whl.metadata (17 kB)
# ...
# Using cached qrcode-8.2-py3-none-any.whl (45 kB)
# ...
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\sinha\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\sinha\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\sinha\anaconda3\Lib\site-packages)
